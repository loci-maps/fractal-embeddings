# %%
import pandas as pd
import numpy as np
import pyvista as pv
from sklearn.preprocessing import MinMaxScaler
import pyvista as pv
from matplotlib.colors import ListedColormap
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# Loads npz 
embeddings_npz = np.load('../sample_data/cohere_memory_embeddings.npz')

rgb_values = embeddings_npz['pca5'][:, 2:5]
xyz = embeddings_npz['pca5'][:,:3]
# Out:
# /Users/aidanbx/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# Displays these pyvista colors in a matplotlib figure

# # Create a colormap from a list of colors
colormap = ListedColormap(rgba_colors)


# # Create a plotter object and set the scalars to the Z height
plotter = pv.Plotter()
plotter.add_mesh(cloud, scalars='point_color', cmap=colormap, show_edges=True)
plotter.show()
# Out:
# /Users/aidanbx/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
rgb_values

# %%
# Out:
# [(255, 0, 0), (0, 255, 0), (0, 0, 255)]

# %%
# Out:
# /Users/aidanbx/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/utilities/helpers.py:507: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 13
#      11 points = [(0, 0, 0), (1, 0, 0), (0, 1, 0)]
#      12 cloud = pv.PolyData(points)
# ---> 13 cloud.point_arrays['colors'] = colors
#      15 # Plot the point cloud
#      16 p = pv.Plotter()
#
# File ~/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/core/dataset.py:122, in DataSet.__getattr__(self, item)
#     120 def __getattr__(self, item) -> Any:
#     121     """Get attribute from base class if not found."""
# --> 122     return super().__getattribute__(item)
#
# AttributeError: 'PolyData' object has no attribute 'point_arrays'

# %%
surf = cloud.delaunay_2d()
surf.plot(show_edges=True)
# Out:
# /Users/aidanbx/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
xyz
# Out:
# array([[ -3.2891708 ,  20.26921087,   0.37509413],
#        [ 46.28816865, -32.35183139,   0.42854952],
#        [ -6.95462035, -11.36995396,   0.44450094],
#        ...,
#        [  3.61893222,   3.45483841,   0.25339689],
#        [ -9.94114972,  -4.31567149,   0.54938898],
#        [ -3.50899604,  15.41381977,   0.2520416 ]])

# %%
# simply pass the numpy points to the PolyData constructor
cloud = pv.PolyData(xyz)
cloud.plot(point_size=15)
# Out:
# /Users/aidanbx/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
points = np.column_stack((xy_array, np.zeros(xy_array.shape[0])))
cloud = pv.PolyData(points)
cloud.point_data['colors'] = rgb_array

surf = cloud.delaunay_2d()

# %%
norm_rgb = rgb_array
colormap = ListedColormap(norm_rgb)

# %%
plotter = pv.Plotter()
plotter.add_mesh(surf, scalars='colors', cmap=colormap, show_edges=True)
plotter.show()
# Out:
# /Users/aidanbx/miniconda/envs/cv/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
