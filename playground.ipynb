# %%
# Reloads the hierarchical_clustering module and runs a test on the sample embeddings CSV file
import importlib
import hierarchical_clustering
importlib.reload(hierarchical_clustering)
# Import the necessary functions from the hierarchical_clustering module
from hierarchical_clustering import build_tree, get_all_centroids, calculate_balance
from scipy.spatial.distance import euclidean


# Test the build_tree() function with a sample embeddings CSV file
embedding_file = "./sample_embeddings.csv"
tree = build_tree(embedding_file)
calculate_balance(tree)

# Check the structure of the tree (e.g., print the number of files in each node)
def print_tree_structure(node, depth=0):
    if node is not None:
        print(f"Depth {depth}: Node has {node.get_children()} files with balance {node.balance}")
        print_tree_structure(node.left, depth+1)
        print_tree_structure(node.right, depth+1)

print_tree_structure(tree)

# Get the centroids for each level
levels = get_all_centroids(tree, embedding_file)

# Function to print statistics for each level
def print_level_stats(levels):
    for level, centroids in enumerate(levels):
        num_centroids = len(centroids)
        distances = [euclidean(centroids[i], centroids[j]) for i in range(num_centroids) for j in range(i + 1, num_centroids)]

        print(f"Level {level}:")
        print(f"  Number of centroids: {num_centroids}")
        if distances:
            min_distance = min(distances)
            max_distance = max(distances)
            avg_distance = sum(distances) / len(distances)
            print(f"  Min distance: {min_distance:.2f}")
            print(f"  Max distance: {max_distance:.2f}")
            print(f"  Avg distance: {avg_distance:.2f}")
        else:
            print("  No distances to calculate")
        print()

# Print statistics for each level
print_level_stats(levels)
# Out:
# Depth 0: Node has 594 files with balance 222
# Depth 1: Node has 1 files with balance 0
# Depth 1: Node has 593 files with balance 221
# Depth 2: Node has 1 files with balance 0
# Depth 2: Node has 592 files with balance 220
# Depth 3: Node has 1 files with balance 0
# Depth 3: Node has 591 files with balance 219
# Depth 4: Node has 1 files with balance 0
# Depth 4: Node has 590 files with balance 218
# Depth 5: Node has 1 files with balance 0
# Depth 5: Node has 589 files with balance 217
# Depth 6: Node has 1 files with balance 0
# Depth 6: Node has 588 files with balance 216
# Depth 7: Node has 1 files with balance 0
# Depth 7: Node has 587 files with balance 215
# Depth 8: Node has 1 files with balance 0
# Depth 8: Node has 586 files with balance 214
# Depth 9: Node has 1 files with balance 0
# Depth 9: Node has 585 files with balance 211
# Depth 10: Node has 3 files with balance 1
# Depth 11: Node has 1 files with balance 0
# Depth 11: Node has 2 files with balance 0
# Depth 12: Node has 1 files with balance 0
# Depth 12: Node has 1 files with balance 0
# Depth 10: Node has 582 files with balance 212
# Depth 11: Node has 1 files with balance 0
# Depth 11: Node has 581 files with balance 210
# Depth 12: Node has 2 files with balance 0
# Depth 13: Node has 1 files with balance 0
# Depth 13: Node has 1 files with balance 0
# Depth 12: Node has 579 files with balance 210
# Depth 13: Node has 1 files with balance 0
# Depth 13: Node has 578 files with balance 208
# Depth 14: Node has 2 files with balance 0
# Depth 15: Node has 1 files with balance 0
# Depth 15: Node has 1 files with balance 0
# Depth 14: Node has 576 files with balance 208
# Depth 15: Node has 1 files with balance 0
# Depth 15: Node has 575 files with balance 207
# Depth 16: Node has 1 files with balance 0
# Depth 16: Node has 574 files with balance 206
# Depth 17: Node has 1 files with balance 0
# Depth 17: Node has 573 files with balance 205
# Depth 18: Node has 1 files with balance 0
# Depth 18: Node has 572 files with balance 203
# Depth 19: Node has 2 files with balance 0
# Depth 20: Node has 1 files with balance 0
# Depth 20: Node has 1 files with balance 0
# Depth 19: Node has 570 files with balance 203
# Depth 20: Node has 1 files with balance 0
# Depth 20: Node has 569 files with balance 202
# Depth 21: Node has 1 files with balance 0
# Depth 21: Node has 568 files with balance 200
# Depth 22: Node has 2 files with balance 0
# Depth 23: Node has 1 files with balance 0
# Depth 23: Node has 1 files with balance 0
# Depth 22: Node has 566 files with balance 200
# Depth 23: Node has 1 files with balance 0
# Depth 23: Node has 565 files with balance 198
# Depth 24: Node has 2 files with balance 0
# Depth 25: Node has 1 files with balance 0
# Depth 25: Node has 1 files with balance 0
# Depth 24: Node has 563 files with balance 198
# Depth 25: Node has 1 files with balance 0
# Depth 25: Node has 562 files with balance 197
# Depth 26: Node has 1 files with balance 0
# Depth 26: Node has 561 files with balance 196
# Depth 27: Node has 1 files with balance 0
# Depth 27: Node has 560 files with balance 192
# Depth 28: Node has 4 files with balance 2
# Depth 29: Node has 1 files with balance 0
# Depth 29: Node has 3 files with balance 1
# Depth 30: Node has 1 files with balance 0
# Depth 30: Node has 2 files with balance 0
# Depth 31: Node has 1 files with balance 0
# Depth 31: Node has 1 files with balance 0
# Depth 28: Node has 556 files with balance 190
# Depth 29: Node has 5 files with balance 3
# Depth 30: Node has 1 files with balance 0
# Depth 30: Node has 4 files with balance 2
# Depth 31: Node has 1 files with balance 0
# Depth 31: Node has 3 files with balance 1
# Depth 32: Node has 1 files with balance 0
# Depth 32: Node has 2 files with balance 0
# Depth 33: Node has 1 files with balance 0
# Depth 33: Node has 1 files with balance 0
# Depth 29: Node has 551 files with balance 190
# Depth 30: Node has 4 files with balance 2
# Depth 31: Node has 1 files with balance 0
# Depth 31: Node has 3 files with balance 1
# Depth 32: Node has 1 files with balance 0
# Depth 32: Node has 2 files with balance 0
# Depth 33: Node has 1 files with balance 0
# Depth 33: Node has 1 files with balance 0
# Depth 30: Node has 547 files with balance 192
# Depth 31: Node has 1 files with balance 0
# Depth 31: Node has 546 files with balance 191
# Depth 32: Node has 1 files with balance 0
# Depth 32: Node has 545 files with balance 186
# Depth 33: Node has 6 files with balance 3
# Depth 34: Node has 1 files with balance 0
# Depth 34: Node has 5 files with balance 1
# Depth 35: Node has 3 files with balance 1
# Depth 36: Node has 1 files with balance 0
# Depth 36: Node has 2 files with balance 0
# Depth 37: Node has 1 files with balance 0
# Depth 37: Node has 1 files with balance 0
# Depth 35: Node has 2 files with balance 0
# Depth 36: Node has 1 files with balance 0
# Depth 36: Node has 1 files with balance 0
# Depth 33: Node has 539 files with balance 189
# Depth 34: Node has 1 files with balance 0
# Depth 34: Node has 538 files with balance 184
# Depth 35: Node has 5 files with balance 3
# Depth 36: Node has 1 files with balance 0
# Depth 36: Node has 4 files with balance 2
# Depth 37: Node has 1 files with balance 0
# Depth 37: Node has 3 files with balance 1
# Depth 38: Node has 1 files with balance 0
# Depth 38: Node has 2 files with balance 0
# Depth 39: Node has 1 files with balance 0
# Depth 39: Node has 1 files with balance 0
# Depth 35: Node has 533 files with balance 187
# Depth 36: Node has 1 files with balance 0
# Depth 36: Node has 532 files with balance 183
# Depth 37: Node has 5 files with balance 1
# Depth 38: Node has 2 files with balance 0
# Depth 39: Node has 1 files with balance 0
# Depth 39: Node has 1 files with balance 0
# Depth 38: Node has 3 files with balance 1
# Depth 39: Node has 1 files with balance 0
# Depth 39: Node has 2 files with balance 0
# Depth 40: Node has 1 files with balance 0
# Depth 40: Node has 1 files with balance 0
# Depth 37: Node has 527 files with balance 183
# Depth 38: Node has 3 files with balance 1
# Depth 39: Node has 1 files with balance 0
# Depth 39: Node has 2 files with balance 0
# Depth 40: Node has 1 files with balance 0
# Depth 40: Node has 1 files with balance 0
# Depth 38: Node has 524 files with balance 184
# Depth 39: Node has 1 files with balance 0
# Depth 39: Node has 523 files with balance 183
# Depth 40: Node has 1 files with balance 0
# Depth 40: Node has 522 files with balance 181
# Depth 41: Node has 2 files with balance 0
# Depth 42: Node has 1 files with balance 0
# Depth 42: Node has 1 files with balance 0
# Depth 41: Node has 520 files with balance 179
# Depth 42: Node has 3 files with balance 1
# Depth 43: Node has 1 files with balance 0
# Depth 43: Node has 2 files with balance 0
# Depth 44: Node has 1 files with balance 0
# Depth 44: Node has 1 files with balance 0
# Depth 42: Node has 517 files with balance 176
# Depth 43: Node has 5 files with balance 3
# Depth 44: Node has 1 files with balance 0
# Depth 44: Node has 4 files with balance 2
# Depth 45: Node has 1 files with balance 0
# Depth 45: Node has 3 files with balance 1
# Depth 46: Node has 1 files with balance 0
# Depth 46: Node has 2 files with balance 0
# Depth 47: Node has 1 files with balance 0
# Depth 47: Node has 1 files with balance 0
# Depth 43: Node has 512 files with balance 179
# Depth 44: Node has 1 files with balance 0
# Depth 44: Node has 511 files with balance 178
# Depth 45: Node has 1 files with balance 0
# Depth 45: Node has 510 files with balance 172
# Depth 46: Node has 6 files with balance 4
# Depth 47: Node has 1 files with balance 0
# Depth 47: Node has 5 files with balance 3
# Depth 48: Node has 1 files with balance 0
# Depth 48: Node has 4 files with balance 2
# Depth 49: Node has 1 files with balance 0
# Depth 49: Node has 3 files with balance 1
# Depth 50: Node has 1 files with balance 0
# Depth 50: Node has 2 files with balance 0
# Depth 51: Node has 1 files with balance 0
# Depth 51: Node has 1 files with balance 0
# Depth 46: Node has 504 files with balance 176
# Depth 47: Node has 1 files with balance 0
# Depth 47: Node has 503 files with balance 170
# Depth 48: Node has 9 files with balance 4
# Depth 49: Node has 1 files with balance 0
# Depth 49: Node has 8 files with balance 1
# Depth 50: Node has 3 files with balance 1
# Depth 51: Node has 1 files with balance 0
# Depth 51: Node has 2 files with balance 0
# Depth 52: Node has 1 files with balance 0
# Depth 52: Node has 1 files with balance 0
# Depth 50: Node has 5 files with balance 1
# Depth 51: Node has 2 files with balance 0
# Depth 52: Node has 1 files with balance 0
# Depth 52: Node has 1 files with balance 0
# Depth 51: Node has 3 files with balance 1
# Depth 52: Node has 1 files with balance 0
# Depth 52: Node has 2 files with balance 0
# Depth 53: Node has 1 files with balance 0
# Depth 53: Node has 1 files with balance 0
# Depth 48: Node has 494 files with balance 174
# Depth 49: Node has 1 files with balance 0
# Depth 49: Node has 493 files with balance 173
# Depth 50: Node has 1 files with balance 0
# Depth 50: Node has 492 files with balance 153
# Depth 51: Node has 32 files with balance 17
# Depth 52: Node has 2 files with balance 0
# Depth 53: Node has 1 files with balance 0
# Depth 53: Node has 1 files with balance 0
# Depth 52: Node has 30 files with balance 17
# Depth 53: Node has 1 files with balance 0
# Depth 53: Node has 29 files with balance 16
# Depth 54: Node has 1 files with balance 0
# Depth 54: Node has 28 files with balance 15
# Depth 55: Node has 1 files with balance 0
# Depth 55: Node has 27 files with balance 13
# Depth 56: Node has 2 files with balance 0
# Depth 57: Node has 1 files with balance 0
# Depth 57: Node has 1 files with balance 0
# Depth 56: Node has 25 files with balance 13
# Depth 57: Node has 1 files with balance 0
# Depth 57: Node has 24 files with balance 12
# Depth 58: Node has 1 files with balance 0
# Depth 58: Node has 23 files with balance 11
# Depth 59: Node has 1 files with balance 0
# Depth 59: Node has 22 files with balance 3
# Depth 60: Node has 14 files with balance 8
# Depth 61: Node has 2 files with balance 0
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 1 files with balance 0
# Depth 61: Node has 12 files with balance 8
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 11 files with balance 5
# Depth 63: Node has 3 files with balance 1
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 2 files with balance 0
# Depth 65: Node has 1 files with balance 0
# Depth 65: Node has 1 files with balance 0
# Depth 63: Node has 8 files with balance 6
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 7 files with balance 5
# Depth 65: Node has 1 files with balance 0
# Depth 65: Node has 6 files with balance 4
# Depth 66: Node has 1 files with balance 0
# Depth 66: Node has 5 files with balance 3
# Depth 67: Node has 1 files with balance 0
# Depth 67: Node has 4 files with balance 2
# Depth 68: Node has 1 files with balance 0
# Depth 68: Node has 3 files with balance 1
# Depth 69: Node has 1 files with balance 0
# Depth 69: Node has 2 files with balance 0
# Depth 70: Node has 1 files with balance 0
# Depth 70: Node has 1 files with balance 0
# Depth 60: Node has 8 files with balance 6
# Depth 61: Node has 1 files with balance 0
# Depth 61: Node has 7 files with balance 5
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 6 files with balance 4
# Depth 63: Node has 1 files with balance 0
# Depth 63: Node has 5 files with balance 3
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 4 files with balance 2
# Depth 65: Node has 1 files with balance 0
# Depth 65: Node has 3 files with balance 1
# Depth 66: Node has 1 files with balance 0
# Depth 66: Node has 2 files with balance 0
# Depth 67: Node has 1 files with balance 0
# Depth 67: Node has 1 files with balance 0
# Depth 51: Node has 460 files with balance 171
# Depth 52: Node has 1 files with balance 0
# Depth 52: Node has 459 files with balance 169
# Depth 53: Node has 2 files with balance 0
# Depth 54: Node has 1 files with balance 0
# Depth 54: Node has 1 files with balance 0
# Depth 53: Node has 457 files with balance 166
# Depth 54: Node has 4 files with balance 2
# Depth 55: Node has 1 files with balance 0
# Depth 55: Node has 3 files with balance 1
# Depth 56: Node has 1 files with balance 0
# Depth 56: Node has 2 files with balance 0
# Depth 57: Node has 1 files with balance 0
# Depth 57: Node has 1 files with balance 0
# Depth 54: Node has 453 files with balance 168
# Depth 55: Node has 1 files with balance 0
# Depth 55: Node has 452 files with balance 159
# Depth 56: Node has 16 files with balance 7
# Depth 57: Node has 1 files with balance 0
# Depth 57: Node has 15 files with balance 2
# Depth 58: Node has 10 files with balance 5
# Depth 59: Node has 1 files with balance 0
# Depth 59: Node has 9 files with balance 4
# Depth 60: Node has 1 files with balance 0
# Depth 60: Node has 8 files with balance 0
# Depth 61: Node has 4 files with balance 2
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 3 files with balance 1
# Depth 63: Node has 1 files with balance 0
# Depth 63: Node has 2 files with balance 0
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 1 files with balance 0
# Depth 61: Node has 4 files with balance 2
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 3 files with balance 1
# Depth 63: Node has 1 files with balance 0
# Depth 63: Node has 2 files with balance 0
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 1 files with balance 0
# Depth 58: Node has 5 files with balance 3
# Depth 59: Node has 1 files with balance 0
# Depth 59: Node has 4 files with balance 2
# Depth 60: Node has 1 files with balance 0
# Depth 60: Node has 3 files with balance 1
# Depth 61: Node has 1 files with balance 0
# Depth 61: Node has 2 files with balance 0
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 1 files with balance 0
# Depth 56: Node has 436 files with balance 166
# Depth 57: Node has 1 files with balance 0
# Depth 57: Node has 435 files with balance 165
# Depth 58: Node has 1 files with balance 0
# Depth 58: Node has 434 files with balance 164
# Depth 59: Node has 1 files with balance 0
# Depth 59: Node has 433 files with balance 151
# Depth 60: Node has 17 files with balance 11
# Depth 61: Node has 1 files with balance 0
# Depth 61: Node has 16 files with balance 10
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 15 files with balance 7
# Depth 63: Node has 3 files with balance 1
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 2 files with balance 0
# Depth 65: Node has 1 files with balance 0
# Depth 65: Node has 1 files with balance 0
# Depth 63: Node has 12 files with balance 8
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 11 files with balance 6
# Depth 65: Node has 2 files with balance 0
# Depth 66: Node has 1 files with balance 0
# Depth 66: Node has 1 files with balance 0
# Depth 65: Node has 9 files with balance 6
# Depth 66: Node has 1 files with balance 0
# Depth 66: Node has 8 files with balance 5
# Depth 67: Node has 1 files with balance 0
# Depth 67: Node has 7 files with balance 4
# Depth 68: Node has 1 files with balance 0
# Depth 68: Node has 6 files with balance 2
# Depth 69: Node has 2 files with balance 0
# Depth 70: Node has 1 files with balance 0
# Depth 70: Node has 1 files with balance 0
# Depth 69: Node has 4 files with balance 2
# Depth 70: Node has 1 files with balance 0
# Depth 70: Node has 3 files with balance 1
# Depth 71: Node has 1 files with balance 0
# Depth 71: Node has 2 files with balance 0
# Depth 72: Node has 1 files with balance 0
# Depth 72: Node has 1 files with balance 0
# Depth 60: Node has 416 files with balance 161
# Depth 61: Node has 2 files with balance 0
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 1 files with balance 0
# Depth 61: Node has 414 files with balance 161
# Depth 62: Node has 1 files with balance 0
# Depth 62: Node has 413 files with balance 160
# Depth 63: Node has 1 files with balance 0
# Depth 63: Node has 412 files with balance 159
# Depth 64: Node has 1 files with balance 0
# Depth 64: Node has 411 files with balance 156
# Depth 65: Node has 3 files with balance 1
# Depth 66: Node has 1 files with balance 0
# Depth 66: Node has 2 files with balance 0
# Depth 67: Node has 1 files with balance 0
# Depth 67: Node has 1 files with balance 0
# Depth 65: Node has 408 files with balance 156
# Depth 66: Node has 2 files with balance 0
# Depth 67: Node has 1 files with balance 0
# Depth 67: Node has 1 files with balance 0
# Depth 66: Node has 406 files with balance 156
# Depth 67: Node has 1 files with balance 0
# Depth 67: Node has 405 files with balance 148
# Depth 68: Node has 11 files with balance 5
# Depth 69: Node has 2 files with balance 0
# Depth 70: Node has 1 files with balance 0
# Depth 70: Node has 1 files with balance 0
# Depth 69: Node has 9 files with balance 5
# Depth 70: Node has 1 files with balance 0
# Depth 70: Node has 8 files with balance 3
# Depth 71: Node has 2 files with balance 0
# Depth 72: Node has 1 files with balance 0
# Depth 72: Node has 1 files with balance 0
# Depth 71: Node has 6 files with balance 2
# Depth 72: Node has 4 files with balance 2
# Depth 73: Node has 1 files with balance 0
# Depth 73: Node has 3 files with balance 1
# Depth 74: Node has 1 files with balance 0
# Depth 74: Node has 2 files with balance 0
# Depth 75: Node has 1 files with balance 0
# Depth 75: Node has 1 files with balance 0
# Depth 72: Node has 2 files with balance 0
# Depth 73: Node has 1 files with balance 0
# Depth 73: Node has 1 files with balance 0
# Depth 68: Node has 394 files with balance 154
# Depth 69: Node has 1 files with balance 0
# Depth 69: Node has 393 files with balance 153
# Depth 70: Node has 1 files with balance 0
# Depth 70: Node has 392 files with balance 147
# Depth 71: Node has 6 files with balance 4
# Depth 72: Node has 1 files with balance 0
# Depth 72: Node has 5 files with balance 3
# Depth 73: Node has 1 files with balance 0
# Depth 73: Node has 4 files with balance 2
# Depth 74: Node has 1 files with balance 0
# Depth 74: Node has 3 files with balance 1
# Depth 75: Node has 1 files with balance 0
# Depth 75: Node has 2 files with balance 0
# Depth 76: Node has 1 files with balance 0
# Depth 76: Node has 1 files with balance 0
# Depth 71: Node has 386 files with balance 149
# Depth 72: Node has 3 files with balance 1
# Depth 73: Node has 1 files with balance 0
# Depth 73: Node has 2 files with balance 0
# Depth 74: Node has 1 files with balance 0
# Depth 74: Node has 1 files with balance 0
# Depth 72: Node has 383 files with balance 150
# Depth 73: Node has 1 files with balance 0
# Depth 73: Node has 382 files with balance 148
# Depth 74: Node has 2 files with balance 0
# Depth 75: Node has 1 files with balance 0
# Depth 75: Node has 1 files with balance 0
# Depth 74: Node has 380 files with balance 148
# Depth 75: Node has 1 files with balance 0
# Depth 75: Node has 379 files with balance 147
# Depth 76: Node has 1 files with balance 0
# Depth 76: Node has 378 files with balance 146
# Depth 77: Node has 1 files with balance 0
# Depth 77: Node has 377 files with balance 145
# Depth 78: Node has 1 files with balance 0
# Depth 78: Node has 376 files with balance 144
# Depth 79: Node has 1 files with balance 0
# Depth 79: Node has 375 files with balance 143
# Depth 80: Node has 1 files with balance 0
# Depth 80: Node has 374 files with balance 142
# Depth 81: Node has 1 files with balance 0
# Depth 81: Node has 373 files with balance 141
# Depth 82: Node has 1 files with balance 0
# Depth 82: Node has 372 files with balance 140
# Depth 83: Node has 1 files with balance 0
# Depth 83: Node has 371 files with balance 136
# Depth 84: Node has 4 files with balance 2
# Depth 85: Node has 1 files with balance 0
# Depth 85: Node has 3 files with balance 1
# Depth 86: Node has 1 files with balance 0
# Depth 86: Node has 2 files with balance 0
# Depth 87: Node has 1 files with balance 0
# Depth 87: Node has 1 files with balance 0
# Depth 84: Node has 367 files with balance 78
# Depth 85: Node has 273 files with balance 137
# Depth 86: Node has 1 files with balance 0
# Depth 86: Node has 272 files with balance 134
# Depth 87: Node has 3 files with balance 1
# Depth 88: Node has 1 files with balance 0
# Depth 88: Node has 2 files with balance 0
# Depth 89: Node has 1 files with balance 0
# Depth 89: Node has 1 files with balance 0
# Depth 87: Node has 269 files with balance 135
# Depth 88: Node has 1 files with balance 0
# Depth 88: Node has 268 files with balance 134
# Depth 89: Node has 1 files with balance 0
# Depth 89: Node has 267 files with balance 133
# Depth 90: Node has 1 files with balance 0
# Depth 90: Node has 266 files with balance 132
# Depth 91: Node has 1 files with balance 0
# Depth 91: Node has 265 files with balance 131
# Depth 92: Node has 1 files with balance 0
# Depth 92: Node has 264 files with balance 129
# Depth 93: Node has 2 files with balance 0
# Depth 94: Node has 1 files with balance 0
# Depth 94: Node has 1 files with balance 0
# Depth 93: Node has 262 files with balance 129
# Depth 94: Node has 1 files with balance 0
# Depth 94: Node has 261 files with balance 128
# Depth 95: Node has 1 files with balance 0
# Depth 95: Node has 260 files with balance 127
# Depth 96: Node has 1 files with balance 0
# Depth 96: Node has 259 files with balance 126
# Depth 97: Node has 1 files with balance 0
# Depth 97: Node has 258 files with balance 125
# Depth 98: Node has 1 files with balance 0
# Depth 98: Node has 257 files with balance 123
# Depth 99: Node has 2 files with balance 0
# Depth 100: Node has 1 files with balance 0
# Depth 100: Node has 1 files with balance 0
# Depth 99: Node has 255 files with balance 123
# Depth 100: Node has 1 files with balance 0
# Depth 100: Node has 254 files with balance 122
# Depth 101: Node has 1 files with balance 0
# Depth 101: Node has 253 files with balance 121
# Depth 102: Node has 1 files with balance 0
# Depth 102: Node has 252 files with balance 120
# Depth 103: Node has 1 files with balance 0
# Depth 103: Node has 251 files with balance 117
# Depth 104: Node has 3 files with balance 1
# Depth 105: Node has 1 files with balance 0
# Depth 105: Node has 2 files with balance 0
# Depth 106: Node has 1 files with balance 0
# Depth 106: Node has 1 files with balance 0
# Depth 104: Node has 248 files with balance 118
# Depth 105: Node has 1 files with balance 0
# Depth 105: Node has 247 files with balance 117
# Depth 106: Node has 1 files with balance 0
# Depth 106: Node has 246 files with balance 116
# Depth 107: Node has 1 files with balance 0
# Depth 107: Node has 245 files with balance 114
# Depth 108: Node has 2 files with balance 0
# Depth 109: Node has 1 files with balance 0
# Depth 109: Node has 1 files with balance 0
# Depth 108: Node has 243 files with balance 114
# Depth 109: Node has 1 files with balance 0
# Depth 109: Node has 242 files with balance 113
# Depth 110: Node has 1 files with balance 0
# Depth 110: Node has 241 files with balance 112
# Depth 111: Node has 1 files with balance 0
# Depth 111: Node has 240 files with balance 111
# Depth 112: Node has 1 files with balance 0
# Depth 112: Node has 239 files with balance 110
# Depth 113: Node has 1 files with balance 0
# Depth 113: Node has 238 files with balance 109
# Depth 114: Node has 1 files with balance 0
# Depth 114: Node has 237 files with balance 108
# Depth 115: Node has 1 files with balance 0
# Depth 115: Node has 236 files with balance 107
# Depth 116: Node has 1 files with balance 0
# Depth 116: Node has 235 files with balance 106
# Depth 117: Node has 1 files with balance 0
# Depth 117: Node has 234 files with balance 105
# Depth 118: Node has 1 files with balance 0
# Depth 118: Node has 233 files with balance 104
# Depth 119: Node has 1 files with balance 0
# Depth 119: Node has 232 files with balance 100
# Depth 120: Node has 5 files with balance 2
# Depth 121: Node has 1 files with balance 0
# Depth 121: Node has 4 files with balance 0
# Depth 122: Node has 2 files with balance 0
# Depth 123: Node has 1 files with balance 0
# Depth 123: Node has 1 files with balance 0
# Depth 122: Node has 2 files with balance 0
# Depth 123: Node has 1 files with balance 0
# Depth 123: Node has 1 files with balance 0
# Depth 120: Node has 227 files with balance 102
# Depth 121: Node has 1 files with balance 0
# Depth 121: Node has 226 files with balance 101
# Depth 122: Node has 1 files with balance 0
# Depth 122: Node has 225 files with balance 100
# Depth 123: Node has 1 files with balance 0
# Depth 123: Node has 224 files with balance 99
# Depth 124: Node has 1 files with balance 0
# Depth 124: Node has 223 files with balance 98
# Depth 125: Node has 1 files with balance 0
# Depth 125: Node has 222 files with balance 97
# Depth 126: Node has 1 files with balance 0
# Depth 126: Node has 221 files with balance 96
# Depth 127: Node has 1 files with balance 0
# Depth 127: Node has 220 files with balance 95
# Depth 128: Node has 1 files with balance 0
# Depth 128: Node has 219 files with balance 94
# Depth 129: Node has 1 files with balance 0
# Depth 129: Node has 218 files with balance 93
# Depth 130: Node has 1 files with balance 0
# Depth 130: Node has 217 files with balance 92
# Depth 131: Node has 1 files with balance 0
# Depth 131: Node has 216 files with balance 91
# Depth 132: Node has 1 files with balance 0
# Depth 132: Node has 215 files with balance 90
# Depth 133: Node has 1 files with balance 0
# Depth 133: Node has 214 files with balance 89
# Depth 134: Node has 1 files with balance 0
# Depth 134: Node has 213 files with balance 88
# Depth 135: Node has 1 files with balance 0
# Depth 135: Node has 212 files with balance 87
# Depth 136: Node has 1 files with balance 0
# Depth 136: Node has 211 files with balance 86
# Depth 137: Node has 1 files with balance 0
# Depth 137: Node has 210 files with balance 85
# Depth 138: Node has 1 files with balance 0
# Depth 138: Node has 209 files with balance 83
# Depth 139: Node has 2 files with balance 0
# Depth 140: Node has 1 files with balance 0
# Depth 140: Node has 1 files with balance 0
# Depth 139: Node has 207 files with balance 83
# Depth 140: Node has 1 files with balance 0
# Depth 140: Node has 206 files with balance 82
# Depth 141: Node has 1 files with balance 0
# Depth 141: Node has 205 files with balance 81
# Depth 142: Node has 1 files with balance 0
# Depth 142: Node has 204 files with balance 79
# Depth 143: Node has 2 files with balance 0
# Depth 144: Node has 1 files with balance 0
# Depth 144: Node has 1 files with balance 0
# Depth 143: Node has 202 files with balance 79
# Depth 144: Node has 1 files with balance 0
# Depth 144: Node has 201 files with balance 77
# Depth 145: Node has 2 files with balance 0
# Depth 146: Node has 1 files with balance 0
# Depth 146: Node has 1 files with balance 0
# Depth 145: Node has 199 files with balance 77
# Depth 146: Node has 1 files with balance 0
# Depth 146: Node has 198 files with balance 76
# Depth 147: Node has 1 files with balance 0
# Depth 147: Node has 197 files with balance 75
# Depth 148: Node has 1 files with balance 0
# Depth 148: Node has 196 files with balance 74
# Depth 149: Node has 1 files with balance 0
# Depth 149: Node has 195 files with balance 73
# Depth 150: Node has 1 files with balance 0
# Depth 150: Node has 194 files with balance 72
# Depth 151: Node has 1 files with balance 0
# Depth 151: Node has 193 files with balance 71
# Depth 152: Node has 1 files with balance 0
# Depth 152: Node has 192 files with balance 69
# Depth 153: Node has 2 files with balance 0
# Depth 154: Node has 1 files with balance 0
# Depth 154: Node has 1 files with balance 0
# Depth 153: Node has 190 files with balance 69
# Depth 154: Node has 1 files with balance 0
# Depth 154: Node has 189 files with balance 68
# Depth 155: Node has 1 files with balance 0
# Depth 155: Node has 188 files with balance 67
# Depth 156: Node has 1 files with balance 0
# Depth 156: Node has 187 files with balance 66
# Depth 157: Node has 1 files with balance 0
# Depth 157: Node has 186 files with balance 65
# Depth 158: Node has 1 files with balance 0
# Depth 158: Node has 185 files with balance 64
# Depth 159: Node has 1 files with balance 0
# Depth 159: Node has 184 files with balance 62
# Depth 160: Node has 2 files with balance 0
# Depth 161: Node has 1 files with balance 0
# Depth 161: Node has 1 files with balance 0
# Depth 160: Node has 182 files with balance 62
# Depth 161: Node has 1 files with balance 0
# Depth 161: Node has 181 files with balance 61
# Depth 162: Node has 1 files with balance 0
# Depth 162: Node has 180 files with balance 60
# Depth 163: Node has 1 files with balance 0
# Depth 163: Node has 179 files with balance 59
# Depth 164: Node has 1 files with balance 0
# Depth 164: Node has 178 files with balance 58
# Depth 165: Node has 1 files with balance 0
# Depth 165: Node has 177 files with balance 57
# Depth 166: Node has 1 files with balance 0
# Depth 166: Node has 176 files with balance 56
# Depth 167: Node has 1 files with balance 0
# Depth 167: Node has 175 files with balance 55
# Depth 168: Node has 1 files with balance 0
# Depth 168: Node has 174 files with balance 54
# Depth 169: Node has 1 files with balance 0
# Depth 169: Node has 173 files with balance 53
# Depth 170: Node has 1 files with balance 0
# Depth 170: Node has 172 files with balance 44
# Depth 171: Node has 14 files with balance 6
# Depth 172: Node has 2 files with balance 0
# Depth 173: Node has 1 files with balance 0
# Depth 173: Node has 1 files with balance 0
# Depth 172: Node has 12 files with balance 3
# Depth 173: Node has 8 files with balance 5
# Depth 174: Node has 1 files with balance 0
# Depth 174: Node has 7 files with balance 4
# Depth 175: Node has 1 files with balance 0
# Depth 175: Node has 6 files with balance 2
# Depth 176: Node has 2 files with balance 0
# Depth 177: Node has 1 files with balance 0
# Depth 177: Node has 1 files with balance 0
# Depth 176: Node has 4 files with balance 2
# Depth 177: Node has 1 files with balance 0
# Depth 177: Node has 3 files with balance 1
# Depth 178: Node has 1 files with balance 0
# Depth 178: Node has 2 files with balance 0
# Depth 179: Node has 1 files with balance 0
# Depth 179: Node has 1 files with balance 0
# Depth 173: Node has 4 files with balance 2
# Depth 174: Node has 1 files with balance 0
# Depth 174: Node has 3 files with balance 1
# Depth 175: Node has 1 files with balance 0
# Depth 175: Node has 2 files with balance 0
# Depth 176: Node has 1 files with balance 0
# Depth 176: Node has 1 files with balance 0
# Depth 171: Node has 158 files with balance 51
# Depth 172: Node has 1 files with balance 0
# Depth 172: Node has 157 files with balance 34
# Depth 173: Node has 27 files with balance 15
# Depth 174: Node has 1 files with balance 0
# Depth 174: Node has 26 files with balance 14
# Depth 175: Node has 1 files with balance 0
# Depth 175: Node has 25 files with balance 13
# Depth 176: Node has 1 files with balance 0
# Depth 176: Node has 24 files with balance 10
# Depth 177: Node has 3 files with balance 1
# Depth 178: Node has 1 files with balance 0
# Depth 178: Node has 2 files with balance 0
# Depth 179: Node has 1 files with balance 0
# Depth 179: Node has 1 files with balance 0
# Depth 177: Node has 21 files with balance 10
# Depth 178: Node has 2 files with balance 0
# Depth 179: Node has 1 files with balance 0
# Depth 179: Node has 1 files with balance 0
# Depth 178: Node has 19 files with balance 10
# Depth 179: Node has 1 files with balance 0
# Depth 179: Node has 18 files with balance 9
# Depth 180: Node has 1 files with balance 0
# Depth 180: Node has 17 files with balance 8
# Depth 181: Node has 1 files with balance 0
# Depth 181: Node has 16 files with balance 7
# Depth 182: Node has 1 files with balance 0
# Depth 182: Node has 15 files with balance 6
# Depth 183: Node has 1 files with balance 0
# Depth 183: Node has 14 files with balance 3
# Depth 184: Node has 3 files with balance 1
# Depth 185: Node has 1 files with balance 0
# Depth 185: Node has 2 files with balance 0
# Depth 186: Node has 1 files with balance 0
# Depth 186: Node has 1 files with balance 0
# Depth 184: Node has 11 files with balance 1
# Depth 185: Node has 7 files with balance 1
# Depth 186: Node has 3 files with balance 1
# Depth 187: Node has 1 files with balance 0
# Depth 187: Node has 2 files with balance 0
# Depth 188: Node has 1 files with balance 0
# Depth 188: Node has 1 files with balance 0
# Depth 186: Node has 4 files with balance 2
# Depth 187: Node has 1 files with balance 0
# Depth 187: Node has 3 files with balance 1
# Depth 188: Node has 1 files with balance 0
# Depth 188: Node has 2 files with balance 0
# Depth 189: Node has 1 files with balance 0
# Depth 189: Node has 1 files with balance 0
# Depth 185: Node has 4 files with balance 2
# Depth 186: Node has 1 files with balance 0
# Depth 186: Node has 3 files with balance 1
# Depth 187: Node has 1 files with balance 0
# Depth 187: Node has 2 files with balance 0
# Depth 188: Node has 1 files with balance 0
# Depth 188: Node has 1 files with balance 0
# Depth 173: Node has 130 files with balance 49
# Depth 174: Node has 1 files with balance 0
# Depth 174: Node has 129 files with balance 48
# Depth 175: Node has 1 files with balance 0
# Depth 175: Node has 128 files with balance 47
# Depth 176: Node has 1 files with balance 0
# Depth 176: Node has 127 files with balance 46
# Depth 177: Node has 1 files with balance 0
# Depth 177: Node has 126 files with balance 45
# Depth 178: Node has 1 files with balance 0
# Depth 178: Node has 125 files with balance 44
# Depth 179: Node has 1 files with balance 0
# Depth 179: Node has 124 files with balance 40
# Depth 180: Node has 5 files with balance 1
# Depth 181: Node has 2 files with balance 0
# Depth 182: Node has 1 files with balance 0
# Depth 182: Node has 1 files with balance 0
# Depth 181: Node has 3 files with balance 1
# Depth 182: Node has 1 files with balance 0
# Depth 182: Node has 2 files with balance 0
# Depth 183: Node has 1 files with balance 0
# Depth 183: Node has 1 files with balance 0
# Depth 180: Node has 119 files with balance 42
# Depth 181: Node has 1 files with balance 0
# Depth 181: Node has 118 files with balance 40
# Depth 182: Node has 2 files with balance 0
# Depth 183: Node has 1 files with balance 0
# Depth 183: Node has 1 files with balance 0
# Depth 182: Node has 116 files with balance 39
# Depth 183: Node has 2 files with balance 0
# Depth 184: Node has 1 files with balance 0
# Depth 184: Node has 1 files with balance 0
# Depth 183: Node has 114 files with balance 39
# Depth 184: Node has 1 files with balance 0
# Depth 184: Node has 113 files with balance 38
# Depth 185: Node has 1 files with balance 0
# Depth 185: Node has 112 files with balance 37
# Depth 186: Node has 1 files with balance 0
# Depth 186: Node has 111 files with balance 36
# Depth 187: Node has 1 files with balance 0
# Depth 187: Node has 110 files with balance 35
# Depth 188: Node has 1 files with balance 0
# Depth 188: Node has 109 files with balance 34
# Depth 189: Node has 1 files with balance 0
# Depth 189: Node has 108 files with balance 31
# Depth 190: Node has 3 files with balance 1
# Depth 191: Node has 1 files with balance 0
# Depth 191: Node has 2 files with balance 0
# Depth 192: Node has 1 files with balance 0
# Depth 192: Node has 1 files with balance 0
# Depth 190: Node has 105 files with balance 28
# Depth 191: Node has 5 files with balance 3
# Depth 192: Node has 1 files with balance 0
# Depth 192: Node has 4 files with balance 2
# Depth 193: Node has 1 files with balance 0
# Depth 193: Node has 3 files with balance 1
# Depth 194: Node has 1 files with balance 0
# Depth 194: Node has 2 files with balance 0
# Depth 195: Node has 1 files with balance 0
# Depth 195: Node has 1 files with balance 0
# Depth 191: Node has 100 files with balance 30
# Depth 192: Node has 2 files with balance 0
# Depth 193: Node has 1 files with balance 0
# Depth 193: Node has 1 files with balance 0
# Depth 192: Node has 98 files with balance 29
# Depth 193: Node has 2 files with balance 0
# Depth 194: Node has 1 files with balance 0
# Depth 194: Node has 1 files with balance 0
# Depth 193: Node has 96 files with balance 29
# Depth 194: Node has 1 files with balance 0
# Depth 194: Node has 95 files with balance 28
# Depth 195: Node has 1 files with balance 0
# Depth 195: Node has 94 files with balance 27
# Depth 196: Node has 1 files with balance 0
# Depth 196: Node has 93 files with balance 14
# Depth 197: Node has 16 files with balance 11
# Depth 198: Node has 1 files with balance 0
# Depth 198: Node has 15 files with balance 10
# Depth 199: Node has 1 files with balance 0
# Depth 199: Node has 14 files with balance 9
# Depth 200: Node has 1 files with balance 0
# Depth 200: Node has 13 files with balance 8
# Depth 201: Node has 1 files with balance 0
# Depth 201: Node has 12 files with balance 7
# Depth 202: Node has 1 files with balance 0
# Depth 202: Node has 11 files with balance 6
# Depth 203: Node has 1 files with balance 0
# Depth 203: Node has 10 files with balance 5
# Depth 204: Node has 1 files with balance 0
# Depth 204: Node has 9 files with balance 1
# Depth 205: Node has 5 files with balance 3
# Depth 206: Node has 1 files with balance 0
# Depth 206: Node has 4 files with balance 2
# Depth 207: Node has 1 files with balance 0
# Depth 207: Node has 3 files with balance 1
# Depth 208: Node has 1 files with balance 0
# Depth 208: Node has 2 files with balance 0
# Depth 209: Node has 1 files with balance 0
# Depth 209: Node has 1 files with balance 0
# Depth 205: Node has 4 files with balance 2
# Depth 206: Node has 1 files with balance 0
# Depth 206: Node has 3 files with balance 1
# Depth 207: Node has 1 files with balance 0
# Depth 207: Node has 2 files with balance 0
# Depth 208: Node has 1 files with balance 0
# Depth 208: Node has 1 files with balance 0
# Depth 197: Node has 77 files with balance 25
# Depth 198: Node has 1 files with balance 0
# Depth 198: Node has 76 files with balance 22
# Depth 199: Node has 4 files with balance 0
# Depth 200: Node has 2 files with balance 0
# Depth 201: Node has 1 files with balance 0
# Depth 201: Node has 1 files with balance 0
# Depth 200: Node has 2 files with balance 0
# Depth 201: Node has 1 files with balance 0
# Depth 201: Node has 1 files with balance 0
# Depth 199: Node has 72 files with balance 23
# Depth 200: Node has 1 files with balance 0
# Depth 200: Node has 71 files with balance 20
# Depth 201: Node has 3 files with balance 1
# Depth 202: Node has 1 files with balance 0
# Depth 202: Node has 2 files with balance 0
# Depth 203: Node has 1 files with balance 0
# Depth 203: Node has 1 files with balance 0
# Depth 201: Node has 68 files with balance 18
# Depth 202: Node has 62 files with balance 20
# Depth 203: Node has 1 files with balance 0
# Depth 203: Node has 61 files with balance 12
# Depth 204: Node has 11 files with balance 6
# Depth 205: Node has 1 files with balance 0
# Depth 205: Node has 10 files with balance 5
# Depth 206: Node has 1 files with balance 0
# Depth 206: Node has 9 files with balance 1
# Depth 207: Node has 4 files with balance 2
# Depth 208: Node has 1 files with balance 0
# Depth 208: Node has 3 files with balance 1
# Depth 209: Node has 1 files with balance 0
# Depth 209: Node has 2 files with balance 0
# Depth 210: Node has 1 files with balance 0
# Depth 210: Node has 1 files with balance 0
# Depth 207: Node has 5 files with balance 3
# Depth 208: Node has 1 files with balance 0
# Depth 208: Node has 4 files with balance 2
# Depth 209: Node has 1 files with balance 0
# Depth 209: Node has 3 files with balance 1
# Depth 210: Node has 1 files with balance 0
# Depth 210: Node has 2 files with balance 0
# Depth 211: Node has 1 files with balance 0
# Depth 211: Node has 1 files with balance 0
# Depth 204: Node has 50 files with balance 18
# Depth 205: Node has 1 files with balance 0
# Depth 205: Node has 49 files with balance 16
# Depth 206: Node has 2 files with balance 0
# Depth 207: Node has 1 files with balance 0
# Depth 207: Node has 1 files with balance 0
# Depth 206: Node has 47 files with balance 16
# Depth 207: Node has 1 files with balance 0
# Depth 207: Node has 46 files with balance 7
# Depth 208: Node has 30 files with balance 14
# Depth 209: Node has 1 files with balance 0
# Depth 209: Node has 29 files with balance 13
# Depth 210: Node has 1 files with balance 0
# Depth 210: Node has 28 files with balance 12
# Depth 211: Node has 1 files with balance 0
# Depth 211: Node has 27 files with balance 11
# Depth 212: Node has 1 files with balance 0
# Depth 212: Node has 26 files with balance 10
# Depth 213: Node has 1 files with balance 0
# Depth 213: Node has 25 files with balance 6
# Depth 214: Node has 4 files with balance 2
# Depth 215: Node has 1 files with balance 0
# Depth 215: Node has 3 files with balance 1
# Depth 216: Node has 1 files with balance 0
# Depth 216: Node has 2 files with balance 0
# Depth 217: Node has 1 files with balance 0
# Depth 217: Node has 1 files with balance 0
# Depth 214: Node has 21 files with balance 8
# Depth 215: Node has 1 files with balance 0
# Depth 215: Node has 20 files with balance 7
# Depth 216: Node has 1 files with balance 0
# Depth 216: Node has 19 files with balance 4
# Depth 217: Node has 3 files with balance 1
# Depth 218: Node has 1 files with balance 0
# Depth 218: Node has 2 files with balance 0
# Depth 219: Node has 1 files with balance 0
# Depth 219: Node has 1 files with balance 0
# Depth 217: Node has 16 files with balance 2
# Depth 218: Node has 12 files with balance 1
# Depth 219: Node has 6 files with balance 0
# Depth 220: Node has 3 files with balance 1
# Depth 221: Node has 1 files with balance 0
# Depth 221: Node has 2 files with balance 0
# Depth 222: Node has 1 files with balance 0
# Depth 222: Node has 1 files with balance 0
# Depth 220: Node has 3 files with balance 1
# Depth 221: Node has 1 files with balance 0
# Depth 221: Node has 2 files with balance 0
# Depth 222: Node has 1 files with balance 0
# Depth 222: Node has 1 files with balance 0
# Depth 219: Node has 6 files with balance 2
# Depth 220: Node has 2 files with balance 0
# Depth 221: Node has 1 files with balance 0
# Depth 221: Node has 1 files with balance 0
# Depth 220: Node has 4 files with balance 2
# Depth 221: Node has 1 files with balance 0
# Depth 221: Node has 3 files with balance 1
# Depth 222: Node has 1 files with balance 0
# Depth 222: Node has 2 files with balance 0
# Depth 223: Node has 1 files with balance 0
# Depth 223: Node has 1 files with balance 0
# Depth 218: Node has 4 files with balance 2
# Depth 219: Node has 1 files with balance 0
# Depth 219: Node has 3 files with balance 1
# Depth 220: Node has 1 files with balance 0
# Depth 220: Node has 2 files with balance 0
# Depth 221: Node has 1 files with balance 0
# Depth 221: Node has 1 files with balance 0
# Depth 208: Node has 16 files with balance 7
# Depth 209: Node has 1 files with balance 0
# Depth 209: Node has 15 files with balance 6
# Depth 210: Node has 1 files with balance 0
# Depth 210: Node has 14 files with balance 1
# Depth 211: Node has 5 files with balance 3
# Depth 212: Node has 1 files with balance 0
# Depth 212: Node has 4 files with balance 2
# Depth 213: Node has 1 files with balance 0
# Depth 213: Node has 3 files with balance 1
# Depth 214: Node has 1 files with balance 0
# Depth 214: Node has 2 files with balance 0
# Depth 215: Node has 1 files with balance 0
# Depth 215: Node has 1 files with balance 0
# Depth 211: Node has 9 files with balance 4
# Depth 212: Node has 1 files with balance 0
# Depth 212: Node has 8 files with balance 1
# Depth 213: Node has 4 files with balance 2
# Depth 214: Node has 1 files with balance 0
# Depth 214: Node has 3 files with balance 1
# Depth 215: Node has 1 files with balance 0
# Depth 215: Node has 2 files with balance 0
# Depth 216: Node has 1 files with balance 0
# Depth 216: Node has 1 files with balance 0
# Depth 213: Node has 4 files with balance 0
# Depth 214: Node has 2 files with balance 0
# Depth 215: Node has 1 files with balance 0
# Depth 215: Node has 1 files with balance 0
# Depth 214: Node has 2 files with balance 0
# Depth 215: Node has 1 files with balance 0
# Depth 215: Node has 1 files with balance 0
# Depth 202: Node has 6 files with balance 1
# Depth 203: Node has 2 files with balance 0
# Depth 204: Node has 1 files with balance 0
# Depth 204: Node has 1 files with balance 0
# Depth 203: Node has 4 files with balance 0
# Depth 204: Node has 2 files with balance 0
# Depth 205: Node has 1 files with balance 0
# Depth 205: Node has 1 files with balance 0
# Depth 204: Node has 2 files with balance 0
# Depth 205: Node has 1 files with balance 0
# Depth 205: Node has 1 files with balance 0
# Depth 85: Node has 94 files with balance 59
# Depth 86: Node has 1 files with balance 0
# Depth 86: Node has 93 files with balance 57
# Depth 87: Node has 2 files with balance 0
# Depth 88: Node has 1 files with balance 0
# Depth 88: Node has 1 files with balance 0
# Depth 87: Node has 91 files with balance 57
# Depth 88: Node has 1 files with balance 0
# Depth 88: Node has 90 files with balance 56
# Depth 89: Node has 1 files with balance 0
# Depth 89: Node has 89 files with balance 55
# Depth 90: Node has 1 files with balance 0
# Depth 90: Node has 88 files with balance 54
# Depth 91: Node has 1 files with balance 0
# Depth 91: Node has 87 files with balance 53
# Depth 92: Node has 1 files with balance 0
# Depth 92: Node has 86 files with balance 51
# Depth 93: Node has 2 files with balance 0
# Depth 94: Node has 1 files with balance 0
# Depth 94: Node has 1 files with balance 0
# Depth 93: Node has 84 files with balance 51
# Depth 94: Node has 1 files with balance 0
# Depth 94: Node has 83 files with balance 49
# Depth 95: Node has 2 files with balance 0
# Depth 96: Node has 1 files with balance 0
# Depth 96: Node has 1 files with balance 0
# Depth 95: Node has 81 files with balance 49
# Depth 96: Node has 1 files with balance 0
# Depth 96: Node has 80 files with balance 48
# Depth 97: Node has 1 files with balance 0
# Depth 97: Node has 79 files with balance 47
# Depth 98: Node has 1 files with balance 0
# Depth 98: Node has 78 files with balance 46
# Depth 99: Node has 1 files with balance 0
# Depth 99: Node has 77 files with balance 45
# Depth 100: Node has 1 files with balance 0
# Depth 100: Node has 76 files with balance 44
# Depth 101: Node has 1 files with balance 0
# Depth 101: Node has 75 files with balance 43
# Depth 102: Node has 1 files with balance 0
# Depth 102: Node has 74 files with balance 41
# Depth 103: Node has 2 files with balance 0
# Depth 104: Node has 1 files with balance 0
# Depth 104: Node has 1 files with balance 0
# Depth 103: Node has 72 files with balance 41
# Depth 104: Node has 1 files with balance 0
# Depth 104: Node has 71 files with balance 40
# Depth 105: Node has 1 files with balance 0
# Depth 105: Node has 70 files with balance 39
# Depth 106: Node has 1 files with balance 0
# Depth 106: Node has 69 files with balance 38
# Depth 107: Node has 1 files with balance 0
# Depth 107: Node has 68 files with balance 36
# Depth 108: Node has 2 files with balance 0
# Depth 109: Node has 1 files with balance 0
# Depth 109: Node has 1 files with balance 0
# Depth 108: Node has 66 files with balance 36
# Depth 109: Node has 1 files with balance 0
# Depth 109: Node has 65 files with balance 33
# Depth 110: Node has 3 files with balance 1
# Depth 111: Node has 1 files with balance 0
# Depth 111: Node has 2 files with balance 0
# Depth 112: Node has 1 files with balance 0
# Depth 112: Node has 1 files with balance 0
# Depth 110: Node has 62 files with balance 34
# Depth 111: Node has 1 files with balance 0
# Depth 111: Node has 61 files with balance 33
# Depth 112: Node has 1 files with balance 0
# Depth 112: Node has 60 files with balance 29
# Depth 113: Node has 5 files with balance 2
# Depth 114: Node has 1 files with balance 0
# Depth 114: Node has 4 files with balance 0
# Depth 115: Node has 2 files with balance 0
# Depth 116: Node has 1 files with balance 0
# Depth 116: Node has 1 files with balance 0
# Depth 115: Node has 2 files with balance 0
# Depth 116: Node has 1 files with balance 0
# Depth 116: Node has 1 files with balance 0
# Depth 113: Node has 55 files with balance 31
# Depth 114: Node has 1 files with balance 0
# Depth 114: Node has 54 files with balance 29
# Depth 115: Node has 2 files with balance 0
# Depth 116: Node has 1 files with balance 0
# Depth 116: Node has 1 files with balance 0
# Depth 115: Node has 52 files with balance 29
# Depth 116: Node has 1 files with balance 0
# Depth 116: Node has 51 files with balance 28
# Depth 117: Node has 1 files with balance 0
# Depth 117: Node has 50 files with balance 27
# Depth 118: Node has 1 files with balance 0
# Depth 118: Node has 49 files with balance 26
# Depth 119: Node has 1 files with balance 0
# Depth 119: Node has 48 files with balance 25
# Depth 120: Node has 1 files with balance 0
# Depth 120: Node has 47 files with balance 24
# Depth 121: Node has 1 files with balance 0
# Depth 121: Node has 46 files with balance 23
# Depth 122: Node has 1 files with balance 0
# Depth 122: Node has 45 files with balance 22
# Depth 123: Node has 1 files with balance 0
# Depth 123: Node has 44 files with balance 21
# Depth 124: Node has 1 files with balance 0
# Depth 124: Node has 43 files with balance 20
# Depth 125: Node has 1 files with balance 0
# Depth 125: Node has 42 files with balance 19
# Depth 126: Node has 1 files with balance 0
# Depth 126: Node has 41 files with balance 18
# Depth 127: Node has 1 files with balance 0
# ...
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()
# /Users/aidanbx/CS/LociMaps/recursive_dr/hierarchical_clustering.py:74: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   centroid = df.loc[df['filename'].isin(files)].mean()

# %%
[1] + [1,[1,2]]
# Out:
# [1, 1, [1, 2]]
